# %% [markdown]
# Neha Jadhav
# Internship Period-1st April-30th April
#
# TASK 1 :Create a barchart or histogram to visualize the disturbance of a categorical or continuous variable such as the distribution of ages
# gender in population

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Use read_csv for .csv files
df = pd.read_csv("C:\\Users\\hp\\Downloads\\archive (2)\\age_gender.csv")

# Display the first few rows
df.head()
df.tail()
df_clean = df[['age', 'gender']].copy()
print(df)
df_clean = df_clean[df_clean['age'] <= 100]
df_clean['gender'] = df_clean['gender'].map({0: 'Male', 1: 'Female'})
df
# Out:
#        age  ethnicity  gender                        img_name  \
# 0        1          2       0  20161219203650636.jpg.chip.jpg
# 1        1          2       0  20161219222752047.jpg.chip.jpg
# 2        1          2       0  20161219222832191.jpg.chip.jpg
# 3        1          2       0  20161220144911423.jpg.chip.jpg
# 4        1          2       0  20161220144914327.jpg.chip.jpg
# ...    ...        ...     ...                             ...
# 23700   99          0       1  20170120221920654.jpg.chip.jpg
# 23701   99          1       1  20170120134639935.jpg.chip.jpg
# 23702   99          2       1  20170110182418864.jpg.chip.jpg
# 23703   99          2       1  20170117195405372.jpg.chip.jpg
# 23704   99          0       1  20170110182052119.jpg.chip.jpg
#
#                                                   pixels
# 0      129 128 128 126 127 130 133 135 139 142 145 14...
# 1      164 74 111 168 169 171 175 182 184 188 193 199...
# ...

# %%
sns.set(style="whitegrid")  # Optional styling
plt.figure(figsize=(10, 6))
sns.histplot(data=df_clean, x='age', hue='gender', bins=30, kde=False, palette='Set2')

# Step 6: Add labels and title
plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
